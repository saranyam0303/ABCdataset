# %% [markdown]
# # Importing Libraries and Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("dataset.csv")
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %% [markdown]
# # The information about the dataset such as data type, number of rows and columns, etc.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      458 non-null    object
#  1   Team      458 non-null    object
#  2   Number    458 non-null    int64
#  3   Position  458 non-null    object
#  4   Age       458 non-null    int64
#  5   Height    458 non-null    object
#  6   Weight    458 non-null    int64
#  7   College   374 non-null    object
#  8   Salary    447 non-null    float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 32.3+ KB

# %% [markdown]
# # Data Preprocessing

# %%
df.describe() 
#The describe() method returns description of the data in the DataFrame
# Out:
#            Number         Age      Weight        Salary
# count  458.000000  458.000000  458.000000  4.470000e+02
# mean    17.713974   26.934498  221.543668  4.833970e+06
# std     15.966837    4.400128   26.343200  5.226620e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000  1.025210e+06
# 50%     13.000000   26.000000  220.000000  2.836186e+06
# 75%     25.000000   30.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  307.000000  2.500000e+07

# %% [markdown]
# # Finding Missing Values

# %%
df.isnull().any()
# Out:
# Name        False
# Team        False
# Number      False
# Position    False
# Age         False
# Height      False
# Weight      False
# College      True
# Salary       True
# dtype: bool

# %% [markdown]
# # The "height" column by replacing it with random numbers between 150 and 180

# %%
df["Height"]=np.random.randint(150, 180,size=len(df))
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     162     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     165     235
# 2     John Holland  Boston Celtics      30       SG   27     171     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     179     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     159     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     178     203
# 454      Raul Neto       Utah Jazz      25       PG   24     154     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     157     256
# 456    Jeff Withey       Utah Jazz      24        C   26     164     231
# 457       Priyanka       Utah Jazz      34        C   25     154     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %% [markdown]
# # bar graph of height of employees

# %%
br=df["Height"].value_counts()
plt.figure(figsize=(9,5))
br.plot.bar( color='g') 
plt.title("Height of employees") 
plt.xlabel("Height") 
plt.ylabel("Number of employees") 
  
plt.show()

# %% [markdown]
# # 1.Distribution of employees across each team and the percentage split relative to the total number of employees.

# %%
#1. Determine the distribution of employees across each team and
#calculate the percentage split relative to the total number of employees.


team_dist = df['Team'].value_counts()
total_employees = len(df)
team_per = (team_dist / total_employees) * 100
print("Distribution of employees across each team:",team_dist)
print("\n Percentage split relative to the total number of employees:",team_per)
# Out:
# Distribution of employees across each team: Team
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# Utah Jazz                 16
# New York Knicks           16
# Milwaukee Bucks           16
# Brooklyn Nets             15
# Portland Trail Blazers    15
# Oklahoma City Thunder     15
# Denver Nuggets            15
# Washington Wizards        15
# Miami Heat                15
# Charlotte Hornets         15
# Atlanta Hawks             15
# San Antonio Spurs         15
# Houston Rockets           15
# Boston Celtics            15
# Indiana Pacers            15
# Detroit Pistons           15
# Cleveland Cavaliers       15
# Chicago Bulls             15
# Sacramento Kings          15
# Phoenix Suns              15
# Los Angeles Lakers        15
# Los Angeles Clippers      15
# Golden State Warriors     15
# Toronto Raptors           15
# Philadelphia 76ers        15
# Dallas Mavericks          15
# Orlando Magic             14
# Minnesota Timberwolves    14
# ...

# %% [markdown]
# # Bar plot distribution of employees across each team

# %%
br=df["Team"].value_counts()
plt.figure(figsize=(9,5))
br.plot.bar( color='b') 
plt.title("No. of Employees Across Each Team") 
plt.xlabel("Team") 
plt.ylabel("Number of employees") 
  
plt.show()

# %% [markdown]
# # 2. Segregate employees based on their positions within the company.

# %%
position_dis = df['Position'].value_counts()

print("Position Distribution:", position_dis)
# Out:
# Position Distribution: Position
# SG    102
# PF    100
# PG     92
# SF     85
# C      79
# Name: count, dtype: int64

# %% [markdown]
# # Graphical Representation of employees and position

# %%
plt.figure(figsize=(5, 5))
sns.countplot(x='Position', data=df,width=.50)
plt.title('Employees and positions')
plt.xlabel('Position')
plt.ylabel('Number of Employees')
plt.show()

# %% [markdown]
# # 3. Identify the predominant age group among employees

# %%
Age_bins = [15 ,20 ,25 ,30 ,35 ,40 ,45 , 50]
Age_label = ['15-19','20-25','26-29', '30-35','36-39','40-45', '45-50']
df['Age_Group'] = pd.cut(df['Age'], bins=Age_bins, labels=Age_label, right=False)
age_group_distribution = df['Age_Group'].value_counts().sort_index()
print("Age Group Distribution:",age_group_distribution)
# Out:
# Age Group Distribution: Age_Group
# 15-19      2
# 20-25    152
# 26-29    182
# 30-35     90
# 36-39     29
# 40-45      3
# 45-50      0
# Name: count, dtype: int64

# %% [markdown]
# # Graphical Representation of age group of employees

# %%
#Graphical Representation of age group of employees

plt.figure(figsize=(5, 5))
sns.countplot(y='Age_Group', data=df,width=.50,palette = "Set2")
plt.title('Employees and Age group')
plt.xlabel('Ages')
plt.ylabel('Number of Employees')
plt.show()

# %% [markdown]
# # 4. Discover which team and position have the highest salary expenditure

# %%
team = df.groupby('Team')['Salary'].sum()
position= df.groupby('Position')['Salary'].sum()
max_team_salary = team.idxmax()
max_position_salary = position.idxmax()

print("Team with Highest Salary Expenditure:", max_team_salary)
print("Position with Highest Salary Expenditure:", max_position_salary)
# Out:
# Team with Highest Salary Expenditure: Cleveland Cavaliers
# Position with Highest Salary Expenditure: C

# %% [markdown]
# # Graphical Representation of Total Salary Expenditure by Team

# %%
plt.figure(figsize=(10, 6))
team.plot(kind='bar', color='y')
plt.title('Total Salary Expenditure by Team')
plt.xlabel('Team')
plt.ylabel('Total Salary ($)')
plt.show()

# %% [markdown]
# # Graphical representation of Total Salary Expenditure by Team

# %%
plt.figure(figsize=(10, 6))
position.plot(kind='bar', color='b')
plt.title('Total Salary Expenditure by Team')
plt.xlabel('Team')
plt.ylabel('Total Salary ($)')
plt.show()

# %% [markdown]
# # 5. correlation between age and salary

# %%
corrl=df['Age'].corr(df['Salary'])
print("correlation between age and salary :",corrl)
# Out:
# correlation between age and salary : 0.21400941226570974

# %% [markdown]
# # Graphical representation of correlation between age and salary

# %%
sns.scatterplot(x="Age", y="Salary", data=df)
# Out:
# <Axes: xlabel='Age', ylabel='Salary'>
